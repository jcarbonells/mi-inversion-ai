# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 47.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 48.5 MB/s eta 0:00:00
# ...

# %%
# 1. Montar Google Drive
print("1️⃣ Montando Google Drive...")
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# 2. Cambiar al directorio del proyecto
import os
PROJECT_DIR = "/content/drive/MyDrive/investment_ai"
if not os.path.exists(PROJECT_DIR):
    raise FileNotFoundError(f"❌ Carpeta no encontrada: {PROJECT_DIR}")
# Out:
# 1️⃣ Montando Google Drive...
# Mounted at /content/drive

# %%
# !streamlit run streamlit_dashboard/app.py --server.port=8080
# Out:
# Usage: streamlit run [OPTIONS] TARGET [ARGS]...
# Try 'streamlit run --help' for help.
#
# Error: Invalid value: File does not exist: streamlit_dashboard/app.py

# %%
import os
BASE = "/content/drive/MyDrive/investment_ai"
REPORTS = f"{BASE}/reports"

print("📁 Archivos generados hasta ahora:")
for f in sorted(os.listdir(REPORTS)):
    if f.endswith(('.csv', '.json', '.md', '.pdf')):
        path = os.path.join(REPORTS, f)
        size = os.path.getsize(path)
        mod_time = os.path.getmtime(path)
        from datetime import datetime
        print(f"  {f} ({size} bytes, {datetime.fromtimestamp(mod_time).strftime('%H:%M')})")
# Out:
# 📁 Archivos generados hasta ahora:
#   ai_dashboard_summary_20250930.md (5611 bytes, 16:31)
#   analisis_mercado_20200429.json (6450 bytes, 10:02)
#   asset_metrics.csv (2465 bytes, 17:38)
#   asset_metrics_latest.json (2863 bytes, 17:38)
#   breaches_asset.csv (1056 bytes, 17:28)
#   breaches_region.csv (105 bytes, 17:28)
#   data_quality_report.csv (1595 bytes, 06:07)
#   data_quality_report.json (2515 bytes, 06:07)
#   etfs_quick_metrics.csv (588 bytes, 06:07)
#   exposure_by_currency.csv (31 bytes, 16:21)
#   exposure_by_region.csv (26 bytes, 16:21)
#   fx_hedge_latest.json (148 bytes, 17:01)
#   fx_hedge_signal.csv (296 bytes, 13:45)
#   fx_usd_hedge_summary.csv (89 bytes, 16:21)
#   indices_quick_metrics.csv (207 bytes, 06:07)
#   liquidity_dashboard_latest.md (2198 bytes, 10:01)
#   liquidity_regime_latest.json (772 bytes, 10:01)
#   market_regime_latest.json (116 bytes, 10:02)
#   master_report_20250930.pdf (24377 bytes, 16:31)
#   performance_summary.json (159 bytes, 14:22)
# ...

# %%
# !tail -f /content/drive/MyDrive/investment_ai/reports/orchestrator_log_*.txt
# Out:
# ==> /content/drive/MyDrive/investment_ai/reports/orchestrator_log_20250928.txt <==
# Cadena ejecutada: 2025-09-28 15:50:31.279620
# Duración: 103 segundos
# 01_data_prep.ipynb: OK
# 02_portfolio_exposure.ipynb: OK
# 03_fx_agent.ipynb: OK
# 04_quant_signals.ipynb: OK
# 05_risk_manager.ipynb: OK
# 06_portfolio_reconstructor.ipynb: OK
# 07_asset_metrics.ipynb: OK
# 08_reporter.ipynb: OK
# ==> /content/drive/MyDrive/investment_ai/reports/orchestrator_log_20250929.txt <==
# 01_data_prep.ipynb: OK
# 02_portfolio_exposure.ipynb: OK
# 06_portfolio_reconstructor.ipynb: OK
# 07_asset_metrics.ipynb: OK
# 11_market_analyst.ipynb: OK
# 12_sectorial_strength.ipynb: OK
# 03_fx_agent.ipynb: OK
# 04_quant_signals.ipynb: OK
# 05_risk_manager.ipynb: OK
# 07_reporter_advanced.ipynb: OK
# ==> /content/drive/MyDrive/investment_ai/reports/orchestrator_log_20250930.txt <==
# 01_data_prep.ipynb: OK
# 02_portfolio_exposure.ipynb: OK
# 06_portfolio_reconstructor.ipynb: OK
# 07_asset_metrics.ipynb: OK
# ...

# %%
import os
from datetime import datetime

REPORTS_DIR = "/content/drive/MyDrive/investment_ai/reports"
print("📁 Archivos generados hasta ahora:")
for f in sorted(os.listdir(REPORTS_DIR)):
    if f.endswith(('.csv', '.json', '.md', '.pdf')):
        path = os.path.join(REPORTS_DIR, f)
        size = os.path.getsize(path)
        mod_time = os.path.getmtime(path)
        print(f"  {f} ({size} bytes, {datetime.fromtimestamp(mod_time).strftime('%H:%M')})")
# Out:
# 📁 Archivos generados hasta ahora:
#   ai_dashboard_summary_20250930.md (5611 bytes, 16:31)
#   analisis_mercado_20200429.json (6450 bytes, 10:02)
#   asset_metrics.csv (2465 bytes, 17:38)
#   asset_metrics_latest.json (2863 bytes, 17:38)
#   breaches_asset.csv (1056 bytes, 17:28)
#   breaches_region.csv (105 bytes, 17:28)
#   data_quality_report.csv (1595 bytes, 06:07)
#   data_quality_report.json (2515 bytes, 06:07)
#   etfs_quick_metrics.csv (588 bytes, 06:07)
#   exposure_by_currency.csv (31 bytes, 16:21)
#   exposure_by_region.csv (26 bytes, 16:21)
#   fx_hedge_latest.json (148 bytes, 17:01)
#   fx_hedge_signal.csv (296 bytes, 13:45)
#   fx_usd_hedge_summary.csv (89 bytes, 16:21)
#   indices_quick_metrics.csv (207 bytes, 06:07)
#   liquidity_dashboard_latest.md (2198 bytes, 10:01)
#   liquidity_regime_latest.json (772 bytes, 10:01)
#   market_regime_latest.json (116 bytes, 10:02)
#   master_report_20250930.pdf (24377 bytes, 16:31)
#   performance_summary.json (159 bytes, 14:22)
# ...
